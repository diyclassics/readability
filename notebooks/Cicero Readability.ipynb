# %% [markdown]
# ## Imports

# %%
import re

from pprint import pprint

from cltk.corpus.latin import latinlibrary
from cltk.tokenize.sentence import TokenizeSentence
from cltk.tokenize.word import WordTokenizer

# %% [markdown]
# ## CLTK Tools

# %%
word_tokenizer = WordTokenizer('latin')
sent_tokenizer = TokenizeSentence('latin')

# %% [markdown]
# ## Process Files

# %%
files = latinlibrary.fileids()
cicero_files = [file for file in files if 'cicero/' in file]
cicero_raw = latinlibrary.raw(cicero_files)

# %% [markdown]
# ## Function for preprocessing texts

# %%
# Preprocess texts
def preprocess(text):    
    
    text = text.lower()
    
    text= re.sub(r'&lt;','<',text)
    text= re.sub(r'&gt;','>',text)    
        
    punctuation ="\"#$%&\'()*+,-/:;<=>@[\]^_`{|}~"
    translator = str.maketrans({key: " " for key in punctuation})
    text = text.translate(translator)
    
    translator = str.maketrans({key: " " for key in '0123456789'})
    text = text.translate(translator)
    
    from cltk.stem.latin.j_v import JVReplacer
    replacer = JVReplacer()
    text = replacer.replace(text)

    remove_list = [r'\bthe\b', r'\blatin\b', r'\blibrary\b', r'\bclassics\b', r'\bpage\b']    
    for pattern in remove_list:
        text = re.sub(pattern, '', text)
    
    return text

# %% [markdown]
# ## Process Texts

# %%
# Assemble a list of all 140 of Cicero's texts
cicero_texts = [latinlibrary.raw(file) for file in cicero_files]
cicero_texts = [preprocess(text) for text in cicero_texts]

# Assemble a list of all 140 of Cicero's titles
cicero_titles = [text.split('\n', 1)[0] for text in cicero_texts]
cicero_titles = [title.split(': ',1)[-1].lower().strip() for title in cicero_titles]

# %%
def sent_count(text):
    sents = sent_tokenizer.tokenize(text)
    return(len(sents))

def word_count(text):
    words = word_tokenizer.tokenize(text)
    return(len(words))

def char_count(text):
    return len(text)

# %%
def ari(text):
    c, w, s = char_count(text), word_count(text), sent_count(text)
    print(c,w,s)
    score = 4.71 * (c / w) + 0.5 * (w / s) - 21.43
    return score

# %%
for text in cicero_texts:
    print(text[:250])
    print('----------')
# Out:
# cicero  academica
#
#
#
#
#
#
#
#
#  m. tulli ciceronis academici libri quattuor
#
#
#
#
# liber primus
#
#
#
#
#
#
#
#
#
#
#
#  liber secundus
#  liber tertius
#
#
#
#
#      in cumano nuper cum mecum
# ----------
# cicero  ad brutum i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad brutum liber primus
#
#
#
#
#
#  i
#  ii
#  iii
#  iu
#  u
#  ui
#  uii
#  uiii
#  ix
#  x
#  xi
#  xii
#  xiii
#  xiu
#  xu
#  xui
#  xuii
#  xuiii
#
#
#
#
#
#   i  scr. eodem die quo ep.  a.          cicero bruto
# ----------
# cicero  ad brutum ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad brutum liber secundus
#
#
#
#
#
#  i
#  ii
#  iii
#  iu
#  u
#
#
#
#
#
#   i  scr. romae ex. m. mart. ant in. apr. a.         . cicero bruto sal.
#
#
#
#  cum haec scribebam  res existim
# ----------
# cicero  de amicitia
#
#
#
#
#
#
#
#
#  m. tulli ciceronis laelius de amicitia
#
#
#
#
#
#
# ----------
# cicero  pro archia
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro a. licinio archia poeta oratio
#
#
#
#
#
# ----------
# cicero  ad atticum i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber primus
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiu xu xui xuii xuiii xix xx
#
#
#
#
#
#  i.       cicero attico sal.  rome  shortly before    iuly
# ----------
# cicero  ad atticum x
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber decimus
#
#
#
#
#
#  i  ii  iii  iiia  nbsp iu  u  ui  uii  uiii  uiiia uiiib ix ixa  x  xi  xii  xiia xiii  xiu  xu  xui  xuii  xuiii
#
#
#
#
#
#   i  scr. in lateri
# ----------
# cicero  ad atticum xi
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber undecimus
#
#
#
#
#
#  i ii iii iu iua u ui uii uiii ix x xi xii xiii xiu xu xui xuii xuiia xuiii xix xx xxi xxii xxiii xxiu xxu
#
#
#
#
#
#   i  scr. in epiro inter
# ----------
# cicero  ad atticum xii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber duo decimus
#
#
#
#
#
#              a                                        a                                                               a      a
# ----------
# cicero  ad atticum xiii
#
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber tertius decimus
#
#
#
#
#
#     a   b            a     a                                                  a                                             a
# ----------
# cicero  ad atticum xiu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber quartus decimus
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiiia xiiib xiu xu xui xuii xuiia xuiii xix xx xxi xxii
#
#
#
#
#
#    .  scr. in suburbano
# ----------
# cicero  ad atticum xu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber quintus decimus
#
#
#
#
#
#     a        a                                    a
#
#
#
#
#
#    .  scr. in puteolano xui k. iun
# ----------
# cicero  ad atticum xui
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber sextus decimus
#
#
#
#
#
#  i ii iii  iu u ui  uii  uiii  ix x xi xii xiii  xiiia xiu xu xui xuia  xuib xuic  xuid  xuie  xuif
#
#
#
#
#
#    .  scr. in puteolano u
# ----------
# cicero  ad atticum ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber secundus
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiu xu xui xuii xuiii xix xx xxi xxii xxiii xxiu xxu
#
#
#
#
#
#   i  scr. romae m. iun. a.
# ----------
# cicero  ad atticum iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber tertius
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiu xu xui xuii xuiii xix xx xxi xxii xxiii xxiu xxu xxui xxuii
#
#
#
#
#
#   i  scr. proficiscens i
# ----------
# cicero  ad atticum iu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber quartus
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiu xu xui xuii xuiii xix
#
#
#
#
#   i  scr. romae med. mn. sept. a.         . cicero attico sal.
#
# ----------
# cicero  ad atticum u
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber quintus
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiu xu xui xuii xuiii xix xx xxi
#
#
#
#
#
#   i  scr. menturnis iii aut prid. non. mai. a.         .
# ----------
# cicero  ad atticum ui
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber sextus
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix
#
#
#
#
#
#   i  scr. laodiceae ui k. mart. a.         . cicero attico sal.
#
#
#
# accepi tuas litteras a. d. quintum
# ----------
# cicero  ad atticum uii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber septimus
#
#
#
#
#
#  i  ii  iii  iu  u  ui  uii  uiii  ix  x  xi  xii  xiii  xiu  xu  xui  xuii  xuiii  xix  xx  xxi  xxii  xxiii  xxiu  xxu  xxu
# ----------
# cicero  ad atticum uiii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber octauus
#
#
#
#
#
#  i  ii  iii  iu  u  ui  uii  uiii  ix  x  xi  xii  xiii  xiu  xu  xui
#
#
#
#
#
#   i  scr. in formiano xiu k. mart a.         . cicero attico
# ----------
# cicero  ad atticum ix
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad atticum liber nonus
#
#
#
#
#
#  i ii iia iii iu u ui ui uii uiic uiii ix ixa ixb x xi xia xii xiii xiiia xiu xu xui xuii xuiii xix
#
#
#
#
#
#   i  scr. in formiano prid. non. ma
# ----------
# pro l. cornelio balbo oratio
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro l. cornelio balbo oratio
#
#
#
#
#
#
#
# ----------
# brutus
#
#
#
#
#
#
#
#
#  m. tulli ciceronis brutus
#
#
#
#
#
#
#
# ----------
# in caecilium oratio
#
#
#
#
#
#
#
#
#  m. tulli ciceronis diuinatio in caecilium oratio
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------
# pro a. caecina oratio
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro a. caecina oratio
#
#
#
#
#
#
# ----------
# pro m. caelio oratio
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro m. caelio oratio
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------
# cicero  in catilinam i
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  oratio in l. catilinam prima
#
#
#
#
#
#
#       i. quo usque tandem abutere  catilina  patientia nos
# ----------
# cicero  in catilinam ii
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  oratio in l. catilinam secunda habita ad populum
#
#
#
#
#
#
#      tandem aliquando  quirites  l. catilinam fur
# ----------
# cicero  in catilinam iii
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  oratio in l. catilinam tertia habita ad populum
#
#
#
# ----------
# cicero  in catilinam iu
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  oratio in l. catilinam quarta habita in senatu
#
#
#
#
#
#
#      uideo  patres c
# ----------
# pro a. cluentio oratio
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro a. cluentio oratio
#
#
#
#
#
#
# ----------
# commentariolum petitionis
#
#
#
#
#
#
#
#
#  q. tulli ciceronis commentariolum petitionis
#
#
#
#
#
#  i. etsi tibi omnia suppetunt ea quae consequi ingenio aut usu homines aut diligentia possunt  tamen amore nostro non sum alienum arbitratus ad te pe
# ----------
# de consulatu suo fragmenta
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de consulatu suo fragmenta
#
#
#
#
#
# de consulatu suo  frg.
#
#
#
#
#
# principio aetherio flammatus iuppiter igni
# uertitur et totum conlustrat lumine mundum
# menteque diuina caelum terr
# ----------
# pro rege deiotaro
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro rege deiotaro ad c. caesarem oratio
#
#
#
#
#
#
# ----------
# cicero  on diuination
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de diuinatione
#
#
#
#
#
#
#  	 liber primus liber secundus
#
#
#
#
# 		 cicero
#
#
# ----------
# de diuinatione liber prior
#
#
#
#
#
#
#
#
#  marci tulli ciceronis de diuinatione liber prior
#
#
#
#
#
#
#
# ----------
# de diuinatione liber alter
#
#
#
#
#
#
#
#
#  marci tulli ciceronis de diuinatione liber alter
#
#
#
#
#
#
#
#
# ----------
# de domo sua
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de domo sua ad pontifices oratio
#
#
#
#
#
#
#
# ----------
# cicero  ad familiares i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber primus ad p. lentulum
#
#
#
#
#
#  i ii iii iu ua ub ui uii uiii ix x
#
#
#
#
#
#  i. scripta est epistula romae idibus ianuariis a.u.c.    . m. cicero s. d. p.
# ----------
# cicero  ad familiares x
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber decimus ad l. plancum et ceteros
#
#
#
#
#
#  i  ii  iii  iu  u  ui  uii  uiii  ix  x  xi  xii  xiii  xiu  xu  xui  xuii  xuiii  xix  xx  xxi  xxii  xxiii  x
# ----------
# cicero  ad familiares xi
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber undecimus ad m. brutum et ceteros
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiiia xiiib  nbsp nbsp xiu xu xui xuii xuiii xix xx xxi xxii xxiii xxiu
# ----------
# cicero  ad familiares xii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber duodecimus ad c. cassium et ceteros
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii  nbsp nbsp xiu xu xui xuii xuiii xix xx xxi xxii xxiii xxiu xxu
# ----------
# cicero  ad familiares xiii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber tertius decimus ad c. memmium et ceteros
#
#
#
#
#
#                  a   b
# ----------
# cicero  ad familiares xiu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber quartus decimus ad terentiam uxorem
#
#
#
#
#
#
#
#
#
#
#
#   i. scr. dyrrhachii a. d. ui. kal
# ----------
# cicero  ad familiares xu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber quintus decimus ad senatum et ceteros
#
#
#
#
#
#
#
#
#
#
#
#
#   i. scr. in cilicia
# ----------
# cicero  ad familiares xui
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber sextus decimus ad tironem
#
#
#
#
#
#
#
#
#
#
#   i. scr. in itinere iii. no
# ----------
# cicero  ad familiares ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber secundus ad c. curionem et ceteros
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiu xu xui xuii xuiii xix
#
#
#
#
#
#  i. m. cicero s. d. curioni ro
# ----------
# cicero  ad familiares iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber tertius ad ap. claudium pulchrum
#
#
#
#
#
#  i  nbsp ii  nbsp iii  nbsp iu  nbsp u  nbsp ui  nbsp uii  nbsp uiii  nbsp ix  nbsp x  nbsp xi  nbsp xii  nbsp
# ----------
# cicero  ad familiares iu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber quartus ad ser. sulpicium et ceteros
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiu xu
#
#
#
#
#  i. scr. in cumano exeunte mense aprili a.u.c.
# ----------
# cicero  ad familiares u
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber quintus ad q. metellum et ceteros
#
#
#
#
#
#  i  ii  iii  iu  u  ui  uii  uiii  ix  xa  xb  xi  xii  xiii  xiu  xu  xui  xuii  xuiii  xix  xx  xxi
#
#
#
#
#
#
# ----------
# cicero  ad familiares ui
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber sextus ad a. torquatum et ceteros
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix xa xb xi xii xiii xiu xu xui xuii xuiii xix xx xxi xxii
#
#
#
#
#
#  i. scr. romae
# ----------
# cicero  ad familiares uii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber septimus ad m. marium et ceteros
#
#
#
#
#
#  i  ii  iii  iu  u  ui  uii  uiii  ix  x  xi  xii  xiii  xiu  xu  xui  xuii  xuiii  xix  xx  xx
# ----------
# cicero  ad familiares uiii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber octauus m. caelii epistulae ad m. tullium ciceronem
#
#
#
#
#
#  i  ii  iii  iu  u  ui  uii  uiii  ix  x  xi  xii  xiii  xiu  xu  xui  xuii
#
#
#
#
#
#  i. s
# ----------
# cicero  ad familiares ix
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad familiares liber nonus ad m. uarronem et ceteros
#
#
#
#
#
#
#  i  ii  iii  iu  u  ui  uii  uiii  ix  x  xi  xii  xiii  xiu  xu  xui  xuii xuiii  xix  xx  xxi  xxii  xxiii  x
# ----------
# cicero  de fato
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de fato
#
#
#
#
#
#
# ----------
# cicero  de finibus i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de finibus bonorum et malorum liber primus
#
#
#
#
#
#
# ----------
# cicero  de finibus ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de finibus bonorum et malorum liber secundus
#
#
#
#
#
#
#
#
# ----------
# cicero  de finibus iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de finibus bonorum et malorum liber tertius
#
#
#
#
#
#
# ----------
# cicero  de finibus iu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de finibus bonorum et malorum liber quartus
#
#
#
#
#
#
# ----------
# cicero  de finibus u
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de finibus bonorum et malorum liber quintus
#
#
#
#
#
#
# ----------
# pro l. flacco
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro l. flacco oratio
#
#
#
#
#
#
# ----------
# pro pro m. fonteio
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro pro m. fonteio oratio
#
#
#
#
#
#
# ----------
# cicero  ad quintum fratrem i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad quintum fratrem liber primus
#
#
#
#
#  i ii iii iu
#
#
#
#
#
#
#  i. scr. romae a. u. c.    . marcus quinto fratri sal.
#
#
# i.  . etsi non dubitabam  quin hanc epistulam m
# ----------
# cicero  ad quintum fratrem ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad quintum fratrem liber secundus
#
#
#
#
#  i ii iii iu  ui uii uiii ix x xi xii xiii xiu xu
#
#
#
#
#  i. scr. romae mense decembri a.u.c.    . marcus quinto fratri salute
# ----------
# cicero  ad quintum fratrem iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis epistularum ad quintum fratrem liber tertius
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix
#
#
#
#
#
#  i. scr. mense septembri  dat. a. d. iii. kal. oct.  a.u.c.    . marcus quinto fratri
# ----------
# oratio de haruspicum responso
#
#
#
#
#
#
#
#
#  m. tulli ciceronis oratio de haruspicum responso in p. clodium in senatu habita
#
#
#
#
#
#
# ----------
# de imperio cn. pompei
#
#
#
#
#
#
#
#
#  de imperio cn. pompei ad quirites oratio
#
#
#
#
#
#
# ----------
# cicero  de inuentione i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de inuentione liber primus
#
#
#
#
#
#
# ----------
# cicero  de inuentione ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de inuentione liber secundus
#
#
#
#
#
#
# ----------
# cicero  de legibus i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de legibus liber primus
#
#
#
#
#
#
# ----------
# cicero  de legibus ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de legibus liber secundus
#
#
#
#
#
#
# ----------
# cicero  de legibus iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de legibus liber tertius
#
#
#
#
#
#
#
#
#
#
#
#
#
#  i
# ----------
# cicero  de lege agraria i
#
#
#
#
#
#
#
#
#  de lege agraria oratio prima contra p. seruilium rullum tr. pleb. in senatu
#
#
#
#
#
#
# ----------
# cicero  de lege agraria ii
#
#
#
#
#
#
#
#
#  de lege agraria oratio secuunda contra p. seruilium rullum tr. pleb. in senatu
#
#
#
#
#
#
# ----------
# cicero  de lege agraria iii
#
#
#
#
#
#
#
#
#  de lege agraria oratio tertia contra p. seruilium rullum tr. pleb. in senatu
#
#
#
#
#
#
#
#
#
#
#
#      commodius fecissent tribuni ple
# ----------
# cicero  pro ligario
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro pro q. ligario oratio
#
#
#
#
#
#
# ----------
# cicero  pro marcello
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro m. marcello oratio
#
#
#
#
#
#
# ----------
# cicero  pro milone
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro t. annio milone oratio
#
#
#
#
#
#
#
#
#
#
#
#  i.  . etsi uereor  iudices  ne turpe si
# ----------
# cicero  pro murena
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro murena oratio
#
#
#
#
#
#
# ----------
# cicero  de natura deorum
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de natura deorum
#
#
#
#
#
#  liber primus liber secundus liber tertius
#
#
#
# 		 cicero
#
#
# ----------
# cicero  de natura deorum i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de natura deorum ad m. brutum liber primus
#
#
#
#
#
#
# ----------
# cicero  de natura deorum ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de natura deorum ad m. brutum liber secundus
#
#
#
#
#
# ----------
# cicero  de natura deorum iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de natura deorum ad m. brutum liber tertius
#
#
#
#
#
#
# ----------
# cicero  de officiis i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de officiis liber primus
#
#
#
#
#
#
# ----------
# cicero  de officiis ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de officiis liber secundus
#
#
#
#
#
#
#
# ----------
# cicero  de officiis iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de officiis liber tertius
#
#
#
#
#
#
#
# ----------
# cicero  de optimo genere oratorum
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de optimo genere oratorum
#
#
#
#
#
#
#
#
#
#
#
#
#  i      oratorum genera es
# ----------
# cicero  orator ad m. brutum
#
#
#
#
#
#
#
#
#  m. tulli ciceronis orator ad m. brutum
#
#
#
#
#
#
# ----------
# cicero  de oratore i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de oratore ad quintum fratrem liber primus
#
#
#
#
#
#
# ----------
# cicero  de oratore ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de oratore ad quintum fratrem liber secundus
#
#
#
#
#
#
# ----------
# cicero  de oratore iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de oratore ad quintum fratrem liber tertius
#
#
#
#
#
#
# ----------
# cicero  paradoxa
#
#
#
#
#
#
#
#
#  m. tulli ciceronis paradoxa ad m. brutum
#
#
#
#
#
#
# ----------
# cicero  de partitione
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de partitione oratio
#
#
#
#
#
#
#     cicero filius. studeo  mi pater  latine ex te audire ea quae mihi tu de ratione dicendi graece tradidisti      si modo tibi est otium  et si uis. cicero
# ----------
# cicero  philippic i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica prima
#
#
#
#
#
#
# ----------
# cicero  philippic x
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica decima
#
#
#
#
#
#
#
#
#
#
#        i  maxi
# ----------
# cicero  philippic xi
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica undecima
#
#
#
#
#
#
# ----------
# cicero  philippic xii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica duodecima
#
#
#
#
#
#
# ----------
# cicero  philippic xiii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica tertia decima
#
#
#
#
#
#
# ----------
# cicero  philippic xiu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica quarta decima
#
#
#
#
#
#
# ----------
# cicero  philippic ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica secunda
#
#
#
#
#
#        i  quonam meo fato  patres conscripti  fieri dicam  ut nemo his annis uiginti rei publicae fuerit hostis  qui non bellum eodem tempo
# ----------
# cicero  philippic iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica tertia
#
#
#
#
#
#
# ----------
# cicero  philippic iu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica quarta
#
#
#
#
#
#
#
#
#
#
#        i  frequentia uestrum incredibilis  quirites  contioque
# ----------
# cicero  philippic u
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica quinta
#
#
#
#
#
#
# ----------
# cicero  philippic ui
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica sexta
#
#
#
#
#
#
#
#
#
#
#
#        i  audita uobis esse arbitror  quirites
# ----------
# cicero  philippic uii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica septima
#
#
#
#
#
#      i  paruis de rebus  sed fortasse necessariis consulimur  patres conscripti. de appia uia et de moneta consul  de lupercis tribunus pl
# ----------
# cicero  philippic uiii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica octaua
#
#
#
#
#
#      i  confusius hesterno die est acta res  c. pansa  quam postulabat institutum consulatus tui. parum mihi uisus es eos  quibus cedere n
# ----------
# cicero  philippic ix
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in m. antonium oratio philippica nona
#
#
#
#
#
#
#
#
#
#
#
#
#        i  uellem di immortales fecissent  patres conscrip
# ----------
# cicero  in pisonem
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in l. calpurnium pisonem oratio
#
#
#
#
#
#
# ----------
# cicero  pro plancio
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro cn. plancio oratio
#
#
#
#
#
#
# ----------
# cicero  post reditum in senatu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis post reditum in senatu oratio
#
#
#
#
#
#     si  patres conscripti  pro uestris immortalibus in me fratremque meum liberosque nostros meritis parum uobis cumulate gratias egero  qua
# ----------
# cicero  post reditum ad quirites
#
#
#
#
#
#
#
#
#  m. tulli ciceronis post reditum ad quirites oratio
#
#
#
#
#
#     quod precatus a ioue optimo maximo ceterisque dis immortalibus sum  quirites  eo tempore  cum me fortunasque meas pro uestra incolum
# ----------
# cicero  de prouinciis consularibus
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de prouinciis consularibus oratio
#
#
#
#
#
#
# ----------
# cicero  pro quinctio
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro p. quinctio oratio
#
#
#
#
#
#
# i. quae res in ciuitate duae plurimum possunt  eae contra nos ambae faciunt in hoc tempore  summa gratia et eloquentia  quarum alterum  c.
# ----------
# cicero  pro rabiro perduellionis
#
#
#
#
#
#
#
#
#  pro c. rabirio perduellionis reo ad quirites oratio
#
#
#
#
#
# ----------
# cicero  pro rabiro postumo
#
#
#
#
#
#
#
#
#  pro c. rabirio postumo oratio
#
#
#
#
#
#
# ----------
# cicero  de re publica i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de re publica liber primus
#
#
#
#
#
#
# ----------
# cicero  de re publica ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de re publica liber secundus
#
#
#
#
#
#
# ----------
# cicero  de re publica iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de re publica liber tertius
#
#
#
#
#
#
#
#
#
#
#
#     et ue
# ----------
# cicero  de re publica iu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de re publica liber quartus
#
#
#
#
#
#
#
#
#
#
#
#      scipio   gratiam  quam commode ordines discripti aetates classes equitatus  in quo suffragia sunt etiam senatus  nimis mult
# ----------
# cicero  de re publica u
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de re publica liber quintus
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       manilius?    nihil esse tam  regale quam explanationem aequitatis  in qua iuris erat interpretatio  quod i
# ----------
# cicero  de re publica ui
#
#
#
#
#
#
#
#
#  m. tulli ciceronis de re publica liber sextus
#
#
#
#
#
#
#
#
#
#
#
#  somnium scipionis
#
#
#
#      scipio
# ----------
# cicero  pro roscio comodeo
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro roscio comodeo oratio
#
#
#
#
#
#
# ----------
# cicero  pro scauro
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro m. scauro oratio
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------
# cicero  de senectute
#
#
#
#
#
#
#
#
#  m. tulli ciceronis cato maior de senectute
#
#
#
#
#
#
# ----------
# cicero  pro sestio
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro p. sestio oratio
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiu xu xui xuii xuiii xix xx xxi xxii xxiii xxiu xxu xxui xxuii xxuiii xxix xxx xxxi xxxii xxxiii xxxiu xxxu xxxui xx
# ----------
# cicero  pro sex. roscio amerino
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro sex. roscio amerino oratio
#
#
#
#
#
#     credo ego uos  iudices  mirari  quid sit  quod  cum tot summi oratores hominesque nobilissimi sedeant  ego potissimum s
# ----------
# cicero  pro sulla
#
#
#
#
#
#
#
#
#  m. tulli ciceronis pro sulla oratio
#
#
#
#
#
#
# ----------
# cicero  topica
#
#
#
#
#
#
#
#
#  m. tulli ciceronis topica
#
#
#
#
#
#      maiores nos res scribere ingressos  c. trebati  et his libris quos breui tempore satis multos edidimus digniores  e cursu ipso reuocauit uoluntas tua. cum enim mecum in tuscu
# ----------
# cicero  tusculan disputations i
#
#
#
#
#
#
#
#
#  m. tulli ciceronis tusculanarum disputationum liber primus
#
#
#
#
#
#   cum defensionum laboribus senatoriisque muneribus aut omnino aut magna ex parte essem aliquando liberatus  rettu
# ----------
# cicero  tusculan disputations ii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis tusculanarum disputationum liber secundus
#
#
#
#
#    neoptolemus quidem apud ennium  philosophari sibi  ait  necesse esse  sed paucis  nam omnino haud placere . ego autem  brute
# ----------
# cicero  tusculan disputations iii
#
#
#
#
#
#
#
#
#  m. tulli ciceronis tusculanarum disputationum liber tertius
#
#
#
#
#
#
#
# ----------
# cicero  tusculan disputations iu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis tusculanarum disputationum liber quartus
#
#
#
#
#
#
#
# ----------
# cicero  tusculan disputations iu
#
#
#
#
#
#
#
#
#  m. tulli ciceronis tusculanarum disputationum liber quintus
#
#
#
#
#
#
#
# ----------
# cicero  in uatinium
#
#
#
#
#
#
#
#
#  m. tulli ciceronis in uatinium oratio
#
#
#
#
#
#
#  i ii iii iu u ui uii uiii ix x xi xii xiii xiu xu xui xuii
#
#
#
#
#
#   i      si tantum modo  uatini  quid indignitas postularet spectare uoluissem  fecissem id
# ----------
# cicero  in uerrem i
#
#
#
#
#
#
#
#
#  in c. uerrem oratio actio prima
#
#
#
#
#
#      quod erat optandum maxime  iudices  et quod unum ad inuidiam uestri ordinis infamiamque iudiciorum sedandam maxime pertinebat  id non humano consilio  sed prope di
# ----------
# cicero  in uerrem ii.
#
#
#
#
#
#
#
#
#  actionis in c. uerrem secundae
# liber primus
#
#
#
#
#
#      neminem uestrum ignorare arbitror  iudices  hunc per hosce dies sermonem uulgi atque hanc opinionem populi romani fuisse  c.uerrem altera actione r
# ----------
# cicero  in uerrem ii.
#
#
#
#
#
#
#
#
#  actionis in c. uerrem secundae
# liber secundus
#
#
#
#
#
#     multa mihi necessario  iudices  praetermittenda sunt  ut possim aliquo modo aliquando de his rebus quae meae fidei commissae sunt dicere. recepi e
# ----------
# cicero  in uerrem ii.
#
#
#
#
#
#
#
#
#  actionis in c. uerrem secundae
# liber tertius
#
#
#
#
#
#     omnes qui alterum  iudices  nullis impulsi inimicitiis  nulla priuatim laesi iniuria  nullo praemio adducti in iudicium rei publicae causa uocant p
# ----------
# cicero  in uerrem ii.
#
#
#
#
#
#
#
#
#  actionis in c. uerrem secundae
# liber quartus
#
#
#
#
#
#      uenio nunc ad istius  quem ad modum ipse appellat  studium  ut amici eius  morbum et insaniam  ut siculi  latrocinium  ego quo nom
# ----------
# cicero  in uerrem ii.
#
#
#
#
#
#
#
#
#  actionis in c. uerrem secundae
# liber quintus
#
#
#
#
#      nemini uideo dubium esse  iudices  quin apertissime c. uerres in sicilia sacra profanaque omnia et priuatim et publice spoliarit  uersatusque sit s
# ----------

# %%
print(preprocess(cicero_texts[0]))

# %%
cicero_edit = cicero_raw
cicero_edit = cicero_edit.lower()

# %%
punctuation ="\"#$%&\'()*+,-/:;<=>@[\]^_`{|}~"
translator = str.maketrans({key: " " for key in punctuation})
cicero_edit = cicero_edit.translate(translator)

# %%
translator = str.maketrans({key: " " for key in '0123456789'})
cicero_edit = cicero_edit.translate(translator)

# %%
from cltk.stem.latin.j_v import JVReplacer
replacer = JVReplacer()

cicero_edit = replacer.replace(cicero_edit)

# %%
remove_list = ['the', 'latin', 'library', 'classics', 'page']
remove_dict = {key: ' ' for key in remove_list}

for k, v in remove_dict.items():
    cicero_edit = cicero_edit.replace(k,v)

# %%
cicero_edit = " ".join(cicero_edit.split('\t'))

# %%
import re
cicero_edit = re.sub(r'\n\s*\n', '\n', cicero_edit)

# %%
cicero_edit = ". ".join(cicero_edit.split('\n'))
cicero_edit = re.sub(' +',' ', cicero_edit)
cicero_edit = re.sub(' \.','.', cicero_edit)
cicero_edit = re.sub('\.\.','.', cicero_edit)

# %%
print(cicero_edit[:1000])

# %%
from cltk.tokenize.sentence import TokenizeSentence
tokenizer = TokenizeSentence('latin')

# %%
cicero_sents = tokenizer.tokenize(cicero_edit)

# %%
cicero_char_count = []
cicero_word_count = []

for sent in cicero_sents:
    cicero_char_count.append(len(sent))
    cicero_word_count.append(len(sent.split()))

# %%
data = list(zip(cicero_sents, cicero_char_count, cicero_word_count))

# %%
data[0]

# %%
def ari(sentence):
    chars = len(sentence)
    words = len(sentence.split())
    ari = 4.71*(chars/words) + 0.5*(words)-21.43
    return ari

# %%
aris =[]

for item in cicero_sents:
    aris.append(ari(item))

# %%
aris.index(max(aris))

# %%
print(data[39497][1])
print(data[39497][2])
print(cicero_sents[39497])

# %%
word_counts = [item[2] for item in data]

# %%
word_counts.index(max(word_counts))

# %%
chars_per_word = [item[1]/item[2] for item in data if item[2] > 1]

# %%
chars_per_word.index(max(chars_per_word))

# %%
cicero_sents[15215]

# %%
sum(word_counts) / len(word_counts)

# %%
char_counts = [item[1] for item in data]

# %%
sum(char_counts) / len(char_counts)

# %%
markers = ["[1]", "[I]", "[ 1 ]", "[ 1]", "I. "]

start = []

for text in cicero_texts:
    temp = len(text)
    for marker in markers:
        if text.find(marker) < temp and text.find(marker) != -1:
            temp = text.index(marker)
    start.append(temp)

print(start)
    
print(cicero_texts[5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9b90b406b59c> in <module>()
#       3 start = []
#       4
# ----> 5 for text in cicero_texts:
#       6     temp = len(text)
#       7     for marker in markers:
#
# NameError: name 'cicero_texts' is not defined

# %%
def dalechall(sentence): 
    chars = len(sentence)
    words = len(sentence.split())
    ari = 4.71*(chars/words) + 0.5*(words)-21.43
    return ari
